# %% [markdown]
# <a href="https://colab.research.google.com/github/Asif-dth/advanced-Python-/blob/main/colab_feb_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")
# Out:
# hello world

# %%
print("hello world")
# Out:
# hello world

# %%
print("hello how are you ",sep=",")
# Out:
# hello how are you

# %%
name='anand'
age='20'
print(name,age)
# Out:
# anand 20

# %%
print(f"My name is (anand) and I am (20) years old")
# Out:
# My name is (anand) and I am (20) years old

# %%
name = input("Enter your name")
Adm_no = input("enter your Adm_no")
address = input("enter your address")
DOB = input("enter your DOB")
phone_no = input("enter your phone_no")
print()
# Out:
# Enter your nameASIF MUHAMMED N
# enter your Adm_noEC23160
# enter your addressmanakattu Vilakom Aashan Manzil Near railway station kaniyapuram
# enter your DOB28/06/2004
# enter your phone_no9446656418

# %%
print(f"name : {name}");
print(f"Adm_no : {Adm_no}");
print(f"address : {address}");
print(f"DOB : {DOB}");
print(f"phone_no : {phone_no}");
# Out:
# name : ASIF MUHAMMED N
# Adm_no : EC23160
# address : manakattu Vilakom Aashan Manzil Near railway station kaniyapuram
# DOB : 28/06/2004
# phone_no : 9446656418

# %%
first_name = "asif"
last_name = "muhammed"
full_name = first_name +" "+last_name
print(full_name)
# Out:
# asif muhammed

# %%
my_text = """it is said that humans are;
 Similar to monkeys but different;
  In terms of intellegence"""
my_text
# Out:
# 'it is said that humans are;\n Similar to monkeys but different;\n  In terms of intellegence'

# %%
news = "the job opportunities are increasing day by day"
print(len(news))
# Out:
# 47

# %%
news[3]
# Out:
# ' '

# %%
news[0]
# Out:
# 't'

# %%
news[0:15]
# Out:
# 'the job opportu'

# %%
news[15:]
# Out:
# 'nities are increasing day by day'

# %%
news[0::]
# Out:
# 'the job opportunities are increasing day by day'

# %%
news[-3]
# Out:
# 'd'

# %%
news
# Out:
# 'the job opportunities are increasing day by day'

# %%
news[15::2]
# Out:
# 'nte r nraigdyb a'

# %%
news.upper()
# Out:
# 'THE JOB OPPORTUNITIES ARE INCREASING DAY BY DAY'

# %%
news.lower()
# Out:
# 'the job opportunities are increasing day by day'

# %%
news.strip()
# Out:
# 'the job opportunities are increasing day by day'

# %%
news.split()
# Out:
# ['the', 'job', 'opportunities', 'are', 'increasing', 'day', 'by', 'day']

# %%
news.replace("increasing","decreasing")
# Out:
# 'the job opportunities are decreasing day by day'

# %%
news.capitalize()
# Out:
# 'The job opportunities are increasing day by day'

# %%
news.isalnum()
# Out:
# False

# %%
news.swapcase()
# Out:
# 'THE JOB OPPORTUNITIES ARE INCREASING DAY BY DAY'

# %%
news.count("o")
# Out:
# 3

# %%
num1 = 20
num2 = 6
print(num1+num2)
# Out:
# 26

# %%
num1-num2
# Out:
# 14

# %%
num1/num2
# Out:
# 3.3333333333333335

# %%
num1*num2
# Out:
# 120

# %%
num1%num2
# Out:
# 2

# %%
num1>num2
# Out:
# True

# %%
num1<num2
# Out:
# False

# %%
num1==num2
# Out:
# False

# %%
num1>=num2
# Out:
# True

# %%
num1<=num2
# Out:
# False

# %%
num1!=num2
# Out:
# True

# %%
print(10>5 and 7>2)
# Out:
# True

# %%
print(10>5 or 7>12)
# Out:
# True

# %%
print(not(10>5 and 7>2))
# Out:
# False

# %%
# in, not in

news
# Out:
# 'the job opportunities are increasing day by day'

# %%
print("opportunities" in news)
# Out:
# True

# %%
num1 = int(input("enter your salary"))
num2 = int(input("enter your expense"))
savings = num1-num2
print(f"your monthly balance is {savings}")
# Out:
# enter your salary20000
# enter your expense6700
# your monthly balance is 13300

# %%
current_salary=10000
new_salary=(current_salary+(current_salary/100*12))
print(f"current_salary is {new_salary}")
# Out:
# current_salary is 11200.0

# %%
num1 = int(input("enter the received amount"))
num2 = 2000
print(num1>=num2)
print(num1%5)
print(num1/5)
# Out:
# enter the received amount30000
# True
# 0
# 6000.0

# %%
groceries = ["milk","bread","eggs","butter","cheese"]
print(groceries)
# Out:
# ['milk', 'bread', 'eggs', 'butter', 'cheese']

# %%
type(groceries)
# Out:
# list

# %%
groceries[0]
# Out:
# 'milk'

# %%
groceries[-1]
# Out:
# 'cheese'

# %%
groceries[:3]
# Out:
# ['milk', 'bread', 'eggs']

# %%
len(groceries)
# Out:
# 5

# %%
new_list = ["apple","orange","banana","kiwi","mango"]

final_list = groceries+new_list
final_list
# Out:
# ['milk',
#  'bread',
#  'eggs',
#  'butter',
#  'cheese',
#  'apple',
#  'orange',
#  'banana',
#  'kiwi',
#  'mango']

# %%
new_list2 = ["chips","biscuits"]
final_list.extend(new_list)

# %%
final_list
# Out:
# ['milk',
#  'bread',
#  'eggs',
#  'butter',
#  'cheese',
#  'apple',
#  'orange',
#  'banana',
#  'kiwi',
#  'mango',
#  'chips',
#  'biscuits',
#  'chips',
#  'biscuits',
#  'chips',
#  'biscuits',
#  'chips',
#  'biscuits',
#  'chips',
#  'biscuits',
#  'chips',
#  'biscuits',
#  'apple',
#  'orange',
#  'banana',
#  'kiwi',
#  'mango',
#  'apple',
#  'orange',
#  'banana',
#  'kiwi',
#  'mango',
#  'apple',
#  'orange',
#  'banana',
#  'kiwi',
#  'mango']

# %%
final_list.append("curd")

# %%
final_list.insert(2,"ice cream")

# %%
final_list.reverse()

# %%
final_list.sort()

# %%
final_list.pop()
# Out:
# 'orange'

# %%
final_list.pop(2)
# Out:
# 'apple'

# %%
final_list.remove("orange")

# %%
final_list.clear()

# %%
final_list
# Out:
# []

# %%
final_list[1:3] = ["pens","pencil"]

# %%
final_list
# Out:
# ['pens', 'pens', 'pencil']

# %%
album = ["broken angel","faded","pal pal"]
print(album)
# Out:
# ['broken angel', 'faded', 'pal pal']

# %%
type(album)
# Out:
# list

# %%
new_list = ["phonk","metal,pop"]

# %%
final_list = album+new_list

# %%
final_list
# Out:
# ['broken angel', 'faded', 'pal pal', 'phonk', 'metal,pop']

# %%
new_list2 = ["memory","your eyes"]

# %%
final_list.extend(new_list2)

# %%
final_list
# Out:
# ['broken angel',
#  'faded',
#  'pal pal',
#  'phonk',
#  'metal,pop',
#  'memory',
#  'your eyes']

# %%
final_list.append("reboot")

# %%
final_list
# Out:
# ['broken angel',
#  'faded',
#  'pal pal',
#  'phonk',
#  'metal,pop',
#  'memory',
#  'your eyes',
#  'reboot']

# %%
final_list.insert(2,"kalyani")

# %%
final_list
# Out:
# ['broken angel',
#  'faded',
#  'kalyani',
#  'pal pal',
#  'phonk',
#  'metal,pop',
#  'memory',
#  'your eyes',
#  'reboot']

# %%
final_list[2="vadd"]
# Out:
#   File "/tmp/ipython-input-774174600.py", line 1
#     final_list[2="vadd"]
#                ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
nums=[10,23,83,13,90,43,5]

# %%
max(nums)
# Out:
# 90

# %%
sum(nums)
# Out:
# 267

# %%
avg=sum(nums)/len(nums)
avg
# Out:
# 38.142857142857146

# %%
min(nums)
# Out:
# 5

# %%
nums.index(max(nums))
# Out:
# 4

# %%
final_list

# %%
fruits = ("apple","banana","orange")
type(fruits)
# Out:
# tuple

# %%
fruits_list = list(fruits)
fruits_list
# Out:
# ['apple', 'banana', 'orange']

# %%
veggies = ("carrot","beans","radish")
type(veggies)
# Out:
# tuple

# %%
fruits += veggies
fruits
# Out:
# ('apple',
#  'banana',
#  'orange',
#  'carrot',
#  'beans',
#  'radish',
#  'carrot',
#  'beans',
#  'radish',
#  'carrot',
#  'beans',
#  'radish')

# %%
len(fruits)
# Out:
# 12

# %%
fruits.index("tuber")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1916142672.py in <cell line: 0>()
# ----> 1 fruits.index("tuber")
#
# ValueError: tuple.index(x): x not in tuple

# %%
fruits = {"apple","apple","orange","lemon"}
type(fruits)
# Out:
# set

# %%
fruits
# Out:
# {'apple', 'lemon', 'orange'}

# %%
vegs = {"onion","tomato"}
fruits.update(vegs)

# %%
fruits
# Out:
# {'apple', 'lemon', 'onion', 'orange', 'tomato'}

# %%
fruits.pop()
# Out:
# 'onion'

# %%
fruits
# Out:
# {'apple', 'lemon', 'orange', 'tomato'}

# %%
fruits.remove("lemon")#.discard

# %%
fruits
# Out:
# {'orange', 'tomato'}

# %%
fruits-vegs
# Out:
# {'orange'}

# %%
fruits.union(vegs)
# Out:
# {'onion', 'orange', 'tomato'}

# %%
car = {
    "brand" : "toyota",
    "model" : "supra",
    "year"  : 2010,
    "cur_year" : 2017

}
car
# Out:
# {'brand': 'toyota', 'model': 'supra', 'year': 2010, 'cur_year': 2017}

# %%
car["brand"]
# Out:
# 'toyota'

# %%
car2 = dict(brand = "toyota",model="supra",year=2010)
car2
# Out:
# {'brand': 'toyota', 'model': 'supra', 'year': 2010}

# %%
car2["model"]
# Out:
# 'supra'

# %%
car2.get("brand")
# Out:
# 'toyota'

# %%
len(car2)
# Out:
# 3

# %%
car2.keys()
# Out:
# dict_keys(['brand', 'model', 'year'])

# %%
car2.values()
# Out:
# dict_values(['toyota', 'supra', 2010])

# %%
car2["model"] = "land cruiser"
car2
# Out:
# {'brand': 'toyota', 'model': 'land cruiser', 'year': 2010}

# %%
car2["colour"] = "white"
car2
# Out:
# {'brand': 'toyota', 'model': 'land cruiser', 'year': 2010, 'colour': 'white'}

# %%
car2.update({"cylinder":6,"engine":"petrol","colour":"black"})

# %%
car2
# Out:
# {'brand': 'toyota',
#  'model': 'land cruiser',
#  'year': 2010,
#  'colour': 'black',
#  'cylinder': 6,
#  'engine': 'petrol'}

# %%
car2.popitem()
car2
# Out:
# {'brand': 'toyota', 'model': 'land cruiser', 'year': 2010}

# %%
car2.pop("brand")
car2
# Out:
# {'model': 'land cruiser', 'year': 2010}

# %%
del car2["model"]
car2
# Out:
# {'year': 2010}

# %%
car2.clear()

# %%
car2
# Out:
# {}

# %%
emp1 = {"name" : "anand",
        "salary": 100000,
        "dept" : "hr"}
emp2 = {"name" : "abdullah",
         "salary" : 10000,
         "dept" : "it"}
emp3 = {"name" : "akber",
        "salary" : 140000,
        "dept" : "finance",
        "grade" : "mi"}

# %%
employees = {
    "employee1": emp1,
    "employee2": emp2,
    "employee3": emp3
}
employees
# Out:
# {'employee1': {'name': 'anand', 'salary': 100000, 'dept': 'hr'},
#  'employee2': {'name': 'abdullah', 'salary': 10000, 'dept': 'it'},
#  'employee3': {'name': 'akber',
#   'salary': 140000,
#   'dept': 'finance',
#   'grade': 'mi'}}

# %%
employees["employee2"]
# Out:
# {'name': 'abdullah', 'salary': 10000, 'dept': 'it'}

# %%
employees["employee3"]
# Out:
# {'name': 'akber', 'salary': 140000, 'dept': 'finance', 'grade': 'mi'}

# %%
contact_book = {"name1" : "anand","phone no1"   : 9456745647,
                "name2" : "abdulla","phone no2" : 9098979695,
                "name3" : "akber","phone no3"   : 9087899790,
                "name4" : "ashkar","phone no4 " : 9087678997,
                "name5" : "adhil","phone no5"   : 9089056433}
contact_book
# Out:
# {'name1': 'anand',
#  'phone no1': 9456745647,
#  'name2': 'abdulla',
#  'phone no2': 9098979695,
#  'name3': 'akber',
#  'phone no3': 9087899790,
#  'name4': 'ashkar',
#  'phone no4 ': 9087678997,
#  'name5': 'adhil',
#  'phone no5': 9089056433}

# %%
contact_book.update({"name6" : "assem","phone":9876543212})
contact_book
# Out:
# {'name1': 'anand',
#  'phone no1': 9456745647,
#  'name2': 'abdulla',
#  'phone no2': 9098979695,
#  'name3': 'akber',
#  'phone no3': 9087899790,
#  'name4': 'ashkar',
#  'phone no4 ': 9087678997,
#  'name5': 'adhil',
#  'phone no5': 9089056433,
#  'name6': 'assem',
#  'phone': 9876543212}

# %%
del contact_book["name6"]

# %%
contact_book
# Out:
# {'name1': 'anand',
#  'phone no1': 9456745647,
#  'name2': 'abdulla',
#  'phone no2': 9098979695,
#  'name3': 'akber',
#  'phone no3': 9087899790,
#  'name4': 'ashkar',
#  'phone no4 ': 9087678997,
#  'name5': 'adhil',
#  'phone no5': 9089056433,
#  'phone': 9876543212}

# %%
contact_book.clear()

# %%
contact_book
# Out:
# {}

# %%
movies = ["avatar","titanic","incredibles","pacafic rim"]
ratings = [9,7,7,9,4,7,5]

movie_rating = dict(zip(movies,ratings))
movie_rating
# Out:
# {'avatar': 9, 'titanic': 7, 'incredibles': 7, 'pacafic rim': 9}

# %%
a=10
b=20
if a>b:
   print("a is greater")
elif a==b:
   print("a and b are equal")
elif b==2*a:
   print("b is twice of a")
else:
   print("b is greater")
# Out:
# b is twice of a

# %%
student_mark=int(input("enter your mark:"))
if student_mark >=90:
  print("a")
elif student_mark >=80:
  print("b")
elif student_mark >=70:
  print("c")
elif student_mark >=60:
  print("d")
else:
  print("fail")
# Out:
# enter your mark:60
# d

# %%
wheater = input("enter your wheater")
if wheater == "sunny":
  print("take suncream")
elif wheater == "rainy":
  print("take umbrella")
elif wheater == "cloudy":
  print("stay at home")
elif wheater == "warm":
  print("take sun glasses")
else:
  print("unknown")
# Out:
# enter your wheaterwarm
# take sun glasses

# %%
student = int(input("enter your age:"))
education = input("enter your education:")
if age >18:
  if education == "higher secondary":
    print("you r eligible for college")
else:
  print("you r not eligible for college but eligible for higher studies")
# Out:
# enter your age:19
# enter your education:7
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-847033392.py in <cell line: 0>()
#       1 student = int(input("enter your age:"))
#       2 education = input("enter your education:")
# ----> 3 if age >18:
#       4   if education == "higher secondary":
#       5     print("you r eligible for college")
#
# NameError: name 'age' is not defined

# %%
mark = 45
result = "pass" if mark>30 else "fail"
if result == "pass":
  print("awarded with grade a")
if result == "fail":
  print("awarded with punishment")
# Out:
# awarded with grade a

# %%
# value_if_true if expression else value_if_false

# %%
temperature = 32
wheater = {"status":"hot" if temperature > 38 else "cold"}
wheater
# Out:
# {'status': 'cold'}

# %%
items = {3200,3400,2300,120,3432}

# %%
price = [3200,234,120,1300,250]
total = sum(price)
print(total)
if total>=5000:
  print("you get a discount of 20 percent and the total amount after discount is",total-total/100*20)
elif total>=3000:
  print("you get a discount of 10 percent and the total amount after discount is ",total-total/100*10)
else:
  print("you get no discount")
# Out:
# 5104
# you get a discount of 20 percent and the total amount after discount is 4083.2

# %%
fruits = ["apple", "mango","orange"]
for fr in fruits:
  print(fr)
# Out:
# apple
# mango
# orange

# %%
for i in range(10):
  print(f"square of (i) is (1*2)")
# Out:
# square of (i) is (1*2)
# square of (i) is (1*2)
# square of (i) is (1*2)
# square of (i) is (1*2)
# square of (i) is (1*2)
# square of (i) is (1*2)
# square of (i) is (1*2)
# square of (i) is (1*2)
# square of (i) is (1*2)
# square of (i) is (1*2)

# %%
groceries_list = ["apples","banana","milk","eggs","radish"]
for item in groceries_list:
  if item =="eggs":
    print("item" ,"found")
    break
  else:
    if item =="banana":
      continue
    print("item is not present")
# Out:
# item is not present
# item is not present
# item found

# %%
savings = [2000,2500,0,3000,1000,5000,2500]
total = 0
for amount in savings:
  if amount == 0:
   continue
  if amount>4000:
   print(f"your savings  is greater than 4000 and your savings is {amount}")
  total += amount
  print(total)
  savings=tuple(savings)
  print(savings)
  savings=list(savings)
# Out:
# 2000
# (2000, 2500, 0, 3000, 1000, 5000, 2500)
# 4500
# (2000, 2500, 0, 3000, 1000, 5000, 2500)
# 7500
# (2000, 2500, 0, 3000, 1000, 5000, 2500)
# 8500
# (2000, 2500, 0, 3000, 1000, 5000, 2500)
# your savings  is greater than 4000 and your savings is 5000
# 13500
# (2000, 2500, 0, 3000, 1000, 5000, 2500)
# 16000
# (2000, 2500, 0, 3000, 1000, 5000, 2500)

# %%
numbers=["1234567890","1097654321","1234534","9954637290","123456789091","23432"]
invalid_count=0
for num in numbers:
 if len(num)==10:
    print("number is not valid")
    invalid_count+=1
    continue
 else:
    print("valid")
    valid_count=+1
    valid_num,add(num)


    print(f"invalid_count is {invalid_count} and valid is {valid_count}")
    print(valid_nums)
# Out:
# number is not valid
# number is not valid
# valid
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1998743055.py in <cell line: 0>()
#       9     print("valid")
#      10     valid_count=+1
# ---> 11     valid_num,add(num)
#      12
#      13
#
# NameError: name 'valid_num' is not defined

# %%
i=1
while i<10:
  print(i**1)
  i+=1
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
savings_goal = 10000
current_sav = 0
monthly_dep = 1500
months = 0
while current_sav < savings_goal:
  current_sav +=monthly_dep
  months +=1
else:
  print("you reached your goal")
  print(f"it will take{months} months to achieve your goal of {savings_goal}")
# Out:
# you reached your goal
# it will take7 months to achieve your goal of 10000

# %%
student_grades = {"anu":85,"nob":56,"bob":78,"dei":43}
for i in student_grades.keys():

  print(i)
# Out:
# anu
# nob
# bob
# dei

# %%
for i,j in student_grades.items():
  print(i," ",j)
  if j>50:
    print(f"(i) scored A grade")
  else:
    print(f"(i) scored B grade")
# Out:
# anu   85
# (i) scored A grade
# nob   56
# (i) scored A grade
# bob   78
# (i) scored A grade
# dei   43
# (i) scored B grade

# %%
emp1 = {"name" : "anand",
        "salary": 100000,
        "dept" : "hr"}
emp2 = {"name" : "abdullah",
         "salary" : 10000,
         "dept" : "it"}
emp3 = {"name" : "akber",
        "salary" : 140000,
        "dept" : "finance",
        "grade" : "mi"}
employees = {
    "employee1": emp1,
    "employee2": emp2,
    "employee3": emp3
}
employees
# Out:
# {'employee1': {'name': 'anand', 'salary': 100000, 'dept': 'hr'},
#  'employee2': {'name': 'abdullah', 'salary': 10000, 'dept': 'it'},
#  'employee3': {'name': 'akber',
#   'salary': 140000,
#   'dept': 'finance',
#   'grade': 'mi'}}

# %%
for emcode,empdetails in employees.items():
  print(empdetails)
# Out:
# {'name': 'anand', 'salary': 100000, 'dept': 'hr'}
# {'name': 'abdullah', 'salary': 10000, 'dept': 'it'}
# {'name': 'akber', 'salary': 140000, 'dept': 'finance', 'grade': 'mi'}

# %%
for empcode,empdetails in employees.items():
  for k,val in empdetails.items():
    if k=="name" and val=="akber":
      print("akber found")
# Out:
# akber found

# %%
a=4
for i in range(1,10):
  print(i)
def facr(a):
  print()
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
def multiply(n):
   print(n*3)
multiply(3)
# Out:
# 9

# %%
def send_gift(recipient,gift):
  print(f"sending {gift} to {recipient}")
send_gift("anand","rajesh")
print()
# Out:
# sending rajesh to anand

# %%
def send_gift(recipient,gift):
  print(f"sending {gift} to {recipient}")
send_gift(gift="his dad",recipient="anand")
# Out:
# sending his dad to anand

# %%
def send_gift(recipient,gift="iphone 17 max pro"):
  print(f"sending {gift} to {recipient}")
send_gift(recipient

# %%
def send_gift(recipient,*gift):
  print(f"sending {gift} to {recipient}")
  send_gift("anand","iphone","samsung","oppo")

# %% [markdown]
# abs() all() any() basestring() bool()

# %%
def book_trip(destination,transport):
 print(f" booking a {transport} to {destination}")
book_trip("miami","cab")
# Out:
#  booking a cab to miami

# %% [markdown]
# same fn with keyword argument

# %%
def book_trip(destination,transport):
 print(f" booking a {transport} to {destination}")
book_trip(destination="miami",transport="cab")
# Out:
#  booking a cab to miami

# %%
def book_trip(destination,transport="cycle"):
  print(f" riding a {transport} to {destination}")
book_trip("ladakh","cycle")
# Out:
#  riding a cycle to ladakh

# %% [markdown]
# arbitary fn

# %%
def book_trip(destination,*things):
  print(f"we are going to {destination} so bring your {things}")
book_trip("beach","bike","peanut")
# Out:
# we are going to beach so bring your ('bike', 'peanut')

# %%
def add_numbers(a,b):
  print(a + b)
results = add_numbers(5,5)
# Out:
# 10

# %%
def add_numbers(a,b):
  return a + b
results = add_numbers(5,5)

# %%
def add_ten(numbers):
  print(numbers+10)
my_result = add_ten(5)
final_answer=my_result*2
# Out:
# 15
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-4065819358.py in <cell line: 0>()
#       2   print(numbers+10)
#       3 my_result = add_ten(5)
# ----> 4 final_answer=my_result*2
#
# TypeError: unsupported operand type(s) for *: 'NoneType' and 'int'

# %%
def add_ten(numbers):
  return numbers+10
my_result = add_ten(5)
final_answer=my_result*2
print(f"the final answer is {final_answer}")
# Out:
# the final answer is 30

# %% [markdown]
# lamda fn

# %%
def square(y):
  sq = y * y
  return sq
square(5)
# Out:
# 25

# %%
re = lambda y:y*y
square(5)
# Out:
# 25

# %%
addition = lambda x,y : x+y
addition(10,20)
# Out:
# 30

# %%
is_pass = lambda marks:"pass" if marks>40 else "fail"
is_pass(55)
# Out:
# 'pass'

# %%
def square(x):
  sq = x * x
  return sq
numbers = [1,2,3,4,5]
squares = map(square,numbers)
list(squares)
# Out:
# [1, 4, 9, 16, 25]

# %%
numbers = [1,2,3,4,5]
squares = map(lambda y:y*y,numbers)
list(squares)
# Out:
# [1, 4, 9, 16, 25]

# %%
list_a = [1,2,3]
list_b = [10,20,30]
sum_lists = list(map(lambda x,y:x+y,list_a,list_b))
sum_lists
# Out:
# [11, 22, 33]

# %%
list_a = [1,-3,2,4,-5,8,-7]
positive_list = list(filter(lambda x:x>0,list_a))
positive_list
# Out:
# [1, 2, 4, 8]

# %% [markdown]
# command at github
# git init
# git clone
# git pull
# git status
# git add
# git commit
# git push
# merge
